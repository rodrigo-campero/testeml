# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_confusion_matrix
from scipy import stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %% [markdown]
# #### Etapa 2:
# ##### Sabendo que os vinhos com notas>=6 são considerados vinhos de boa qualidade (para os vinhos brancos) como posso selecionar no momento da importação os vinhos de boa qualidade?

# %%
wine_white = pd.read_csv("./winequality-white.csv", sep=";")

# %%
wine_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
wine_white.columns = wine_white.columns.str.strip().str.replace(' ', '_').str.lower()

# %%
wine_white.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
wine_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4898 non-null   float64
#  1   volatile_acidity      4898 non-null   float64
#  2   citric_acid           4898 non-null   float64
#  3   residual_sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free_sulfur_dioxide   4898 non-null   float64
#  6   total_sulfur_dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   ph                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# ##### 1.	Definição da variável resposta

# %%
wine_white['target'] = wine_white['quality'].map(lambda x: 1 if x >= 6 else 0).astype(int)
wine_white.drop(['quality'], axis=1, inplace=True)

# %%
X = wine_white.iloc[:, wine_white.columns != 'target']

y = wine_white['target']

# %%
X.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int32

# %% [markdown]
# ##### 2.	Análise Exploratória dos dados

# %%
wine_white.describe().T
# Out:
#                        count        mean        std      min         25%  \
# fixed_acidity         4898.0    6.854788   0.843868  3.80000    6.300000
# volatile_acidity      4898.0    0.278241   0.100795  0.08000    0.210000
# citric_acid           4898.0    0.334192   0.121020  0.00000    0.270000
# residual_sugar        4898.0    6.391415   5.072058  0.60000    1.700000
# chlorides             4898.0    0.045772   0.021848  0.00900    0.036000
# free_sulfur_dioxide   4898.0   35.308085  17.007137  2.00000   23.000000
# total_sulfur_dioxide  4898.0  138.360657  42.498065  9.00000  108.000000
# density               4898.0    0.994027   0.002991  0.98711    0.991723
# ph                    4898.0    3.188267   0.151001  2.72000    3.090000
# sulphates             4898.0    0.489847   0.114126  0.22000    0.410000
# alcohol               4898.0   10.514267   1.230621  8.00000    9.500000
# target                4898.0    0.665169   0.471979  0.00000    0.000000
#
#                             50%       75%        max
# fixed_acidity           6.80000    7.3000   14.20000
# volatile_acidity        0.26000    0.3200    1.10000
# citric_acid             0.32000    0.3900    1.66000
# residual_sugar          5.20000    9.9000   65.80000
# chlorides               0.04300    0.0500    0.34600
# free_sulfur_dioxide    34.00000   46.0000  289.00000
# total_sulfur_dioxide  134.00000  167.0000  440.00000
# density                 0.99374    0.9961    1.03898
# ph                      3.18000    3.2800    3.82000
# sulphates               0.47000    0.5500    1.08000
# alcohol                10.40000   11.4000   14.20000
# target                  1.00000    1.0000    1.00000

# %%
pd.DataFrame(zip(wine_white.isnull().sum(), wine_white.isnull().sum()/len(wine_white)), columns=['Count', 'Proportion'], index=wine_white.columns)
# Out:
#                       Count  Proportion
# fixed_acidity             0         0.0
# volatile_acidity          0         0.0
# citric_acid               0         0.0
# residual_sugar            0         0.0
# chlorides                 0         0.0
# free_sulfur_dioxide       0         0.0
# total_sulfur_dioxide      0         0.0
# density                   0         0.0
# ph                        0         0.0
# sulphates                 0         0.0
# alcohol                   0         0.0
# target                    0         0.0

# %%
(wine_white['target'].count() / wine_white.shape[0]) * 100
# Out:
# 100.0

# %%
correlation = wine_white.corr()
plot = sns.heatmap(correlation, annot=True, fmt=".1f", linewidths=0.6)
plot
# Out:
# <AxesSubplot:>

# %%
sfs = SFS(
    RandomForestClassifier(),
    k_features=10,
    forward=True,
    floating=False,
    scoring="r2",
    cv=0,
)

sfs.fit(X, y)


df_SFS_results = pd.DataFrame(sfs.subsets_).transpose()
print(df_SFS_results)
# Out:
#                         feature_idx               cv_scores avg_score  \
# 1                              (7,)  [-0.07253065624578903] -0.072531
# 2                            (6, 7)    [0.9211644133015916]  0.921164
# 3                         (0, 6, 7)                   [1.0]       1.0
# 4                      (0, 1, 6, 7)                   [1.0]       1.0
# 5                   (0, 1, 2, 6, 7)                   [1.0]       1.0
# 6                (0, 1, 2, 3, 6, 7)                   [1.0]       1.0
# 7             (0, 1, 2, 3, 4, 6, 7)                   [1.0]       1.0
# 8          (0, 1, 2, 3, 4, 6, 7, 8)                   [1.0]       1.0
# 9       (0, 1, 2, 3, 4, 6, 7, 8, 9)                   [1.0]       1.0
# 10  (0, 1, 2, 3, 4, 6, 7, 8, 9, 10)                   [1.0]       1.0
#
#                                         feature_names
# 1                                          (density,)
# 2                     (total_sulfur_dioxide, density)
# 3      (fixed_acidity, total_sulfur_dioxide, density)
# 4   (fixed_acidity, volatile_acidity, total_sulfur...
# 5   (fixed_acidity, volatile_acidity, citric_acid,...
# 6   (fixed_acidity, volatile_acidity, citric_acid,...
# 7   (fixed_acidity, volatile_acidity, citric_acid,...
# 8   (fixed_acidity, volatile_acidity, citric_acid,...
# 9   (fixed_acidity, volatile_acidity, citric_acid,...
# 10  (fixed_acidity, volatile_acidity, citric_acid,...

# %%
fig = plt.figure(figsize=[20, 20])
cols = wine_white.columns
count = 1
for col in cols:
    plt.subplot(4, 4, count)
    sns.histplot(wine_white[col], color="blue", kde=True, stat="density", linewidth=0)
    sns.kdeplot(wine_white[col], color="red", warn_singular=False)
    count+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 3.	Exclusão de outliers, caso necessário (sempre explicando a opção) e a quantidade final após a exclusão.

# %%
fig = plt.figure(figsize=[20, 20])
cols = wine_white.columns
count = 1
for col in cols:
    plt.subplot(4, 4, count)
    sns.boxplot(data=wine_white, x="target", y=col, palette="pastel")
    count+=1
plt.show()

# %%
wine_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4898 non-null   float64
#  1   volatile_acidity      4898 non-null   float64
#  2   citric_acid           4898 non-null   float64
#  3   residual_sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free_sulfur_dioxide   4898 non-null   float64
#  6   total_sulfur_dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   ph                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  target                4898 non-null   int32
# dtypes: float64(11), int32(1)
# memory usage: 440.2 KB

# %%
wine_white = wine_white[(np.abs(stats.zscore(wine_white)) < 3).all(axis=1)]

# %%
fig = plt.figure(figsize=[20, 20])
cols = wine_white.columns
count = 1
for col in cols:
    plt.subplot(4, 4, count)
    sns.histplot(wine_white[col], color="blue", kde=True, stat="density", linewidth=0)
    sns.kdeplot(wine_white[col], color="red", warn_singular=False)
    count+=1
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=[20, 20])
cols = wine_white.columns
count = 1
for col in cols:
    plt.subplot(4, 4, count)
    sns.boxplot(data=wine_white, x="target", y=col, palette="pastel")
    count+=1
plt.show()

# %%
wine_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4502 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4502 non-null   float64
#  1   volatile_acidity      4502 non-null   float64
#  2   citric_acid           4502 non-null   float64
#  3   residual_sugar        4502 non-null   float64
#  4   chlorides             4502 non-null   float64
#  5   free_sulfur_dioxide   4502 non-null   float64
#  6   total_sulfur_dioxide  4502 non-null   float64
#  7   density               4502 non-null   float64
#  8   ph                    4502 non-null   float64
#  9   sulphates             4502 non-null   float64
#  10  alcohol               4502 non-null   float64
#  11  target                4502 non-null   int32
# dtypes: float64(11), int32(1)
# memory usage: 568.7 KB

# %% [markdown]
# ##### 4.	Amostra de Treinamento dos modelos e Validação

# %%
X = wine_white.iloc[:, wine_white.columns != 'target']

y = wine_white['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state=25)

X_train.shape, X_test.shape
# Out:
# ((3151, 11), (1351, 11))

# %% [markdown]
# #### 5.	Padronização dos dados, caso necessário

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# #### 7.	Com a métrica correta faça a comparação entre os diferentes algoritmos e qual foi o melhor entre eles.

# %%
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = model_lr.predict(X_test)
accuracy=accuracy_score(y_test, pred)
print('Accuracy : ', 100 * accuracy)
# Out:
# Accuracy :  77.2760917838638

# %%
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[214 217]
#  [ 90 830]]

# %%
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True)
plt.show()

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.50      0.58       431
#            1       0.79      0.90      0.84       920
#
#     accuracy                           0.77      1351
#    macro avg       0.75      0.70      0.71      1351
# weighted avg       0.76      0.77      0.76      1351

# %%
model_svc = SVC(kernel="rbf")
model_svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
pred = model_svc.predict(X_test)
accuracy=accuracy_score(y_test, pred)
print('Accuracy : ', 100 * accuracy)
# Out:
# Accuracy :  81.79126572908957

# %%
cm = confusion_matrix(y_test, model_svc.predict(X_test))
print(cm)
# Out:
# [[270 161]
#  [ 85 835]]

# %%
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True)
plt.show()

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.63      0.69       431
#            1       0.84      0.91      0.87       920
#
#     accuracy                           0.82      1351
#    macro avg       0.80      0.77      0.78      1351
# weighted avg       0.81      0.82      0.81      1351

# %%
model_knn = KNeighborsClassifier(n_neighbors=20)
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred = model_knn.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print('Accuracy : ', 100 * accuracy)
# Out:
# Accuracy :  79.27461139896373

# %%
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[249 182]
#  [ 98 822]]

# %%
fig, ax = plot_confusion_matrix(conf_mat=cm,
                                show_absolute=True,
                                show_normed=True,
                                colorbar=True)
plt.show()

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.58      0.64       431
#            1       0.82      0.89      0.85       920
#
#     accuracy                           0.79      1351
#    macro avg       0.77      0.74      0.75      1351
# weighted avg       0.79      0.79      0.79      1351
